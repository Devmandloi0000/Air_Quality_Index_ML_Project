# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("E:\\For_Job\\Internship_Ineuron\\Air_Quality_Index\\Code\\notebook\\data\\city_day.csv")

# %%
data.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
data.shape
# Out:
# (29531, 16)

# %%
data.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
from pymongo import MongoClient

# %%
url = f"mongodb+srv://devmandloi37:devmandloi@cluster0.rkgp8jf.mongodb.net/?retryWrites=true&w=majority"

# %%
client=MongoClient(url)

# %%
DB= client['Air_Quality_Index']
col=DB['Air_Quality_Index_Dataset']

# %%
data.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
my_list_data=data.to_dict(orient='records')

# %%
my_list_data
# Out:
# [{'City': 'Ahmedabad',
#   'Date': '2015-01-01',
#   'PM2.5': nan,
#   'PM10': nan,
#   'NO': 0.92,
#   'NO2': 18.22,
#   'NOx': 17.15,
#   'NH3': nan,
#   'CO': 0.92,
#   'SO2': 27.64,
#   'O3': 133.36,
#   'Benzene': 0.0,
#   'Toluene': 0.02,
#   'Xylene': 0.0,
#   'AQI': nan,
#   'AQI_Bucket': nan},
#  {'City': 'Ahmedabad',
#   'Date': '2015-01-02',
#   'PM2.5': nan,
#   'PM10': nan,
#   'NO': 0.97,
#   'NO2': 15.69,
#   'NOx': 16.46,
#   'NH3': nan,
#   'CO': 0.97,
#   'SO2': 24.55,
#   'O3': 34.06,
#   'Benzene': 3.68,
#   'Toluene': 5.5,
#   'Xylene': 3.77,
#   'AQI': nan,
#   'AQI_Bucket': nan},
#  {'City': 'Ahmedabad',
#   'Date': '2015-01-03',
#   'PM2.5': nan,
#   'PM10': nan,
#   'NO': 17.4,
#   'NO2': 19.3,
#   'NOx': 29.7,
#   'NH3': nan,
#   'CO': 17.4,
#   'SO2': 29.07,
#   'O3': 30.7,
#   'Benzene': 6.8,
#   'Toluene': 16.4,
#   'Xylene': 2.25,
#   'AQI': nan,
#   'AQI_Bucket': nan},
#  {'City': 'Ahmedabad',
#   'Date': '2015-01-04',
#   'PM2.5': nan,
# ...

# %%
#col.insert_many(my_list_data)
# Out:
# InsertManyResult([ObjectId('655b464db56824adcf957d38'), ObjectId('655b464db56824adcf957d39'), ObjectId('655b464db56824adcf957d3a'), ObjectId('655b464db56824adcf957d3b'), ObjectId('655b464db56824adcf957d3c'), ObjectId('655b464db56824adcf957d3d'), ObjectId('655b464db56824adcf957d3e'), ObjectId('655b464db56824adcf957d3f'), ObjectId('655b464db56824adcf957d40'), ObjectId('655b464db56824adcf957d41'), ObjectId('655b464db56824adcf957d42'), ObjectId('655b464db56824adcf957d43'), ObjectId('655b464db56824adcf957d44'), ObjectId('655b464db56824adcf957d45'), ObjectId('655b464db56824adcf957d46'), ObjectId('655b464db56824adcf957d47'), ObjectId('655b464db56824adcf957d48'), ObjectId('655b464db56824adcf957d49'), ObjectId('655b464db56824adcf957d4a'), ObjectId('655b464db56824adcf957d4b'), ObjectId('655b464db56824adcf957d4c'), ObjectId('655b464db56824adcf957d4d'), ObjectId('655b464db56824adcf957d4e'), ObjectId('655b464db56824adcf957d4f'), ObjectId('655b464db56824adcf957d50'), ObjectId('655b464db56824adcf95
# ...

# %%
query={}
a= col.find(query)
df = pd.DataFrame(list(a))

# %%
df.drop('_id',inplace=True,axis=1)

# %%
df.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
df.shape
# Out:
# (29531, 16)

# %% [markdown]
# 1. Particulate Matter (PM10 & PM2.5)
# pm2.5 iconA mixture of particles with liquid droplets in the air forms particulate matter. PM 10 are particles that have a size of less than or equal to 10 microns whereas PM2.5 are ultra-fine particles having a size of less than or equal to 2.5 microns.
#
# 2. Carbon Monoxide
# co gas iconSources:
# It is a colorless gas, released from automobile emissions, fires, industrial processes, gas stoves, kitchen chimneys, generators, wood-burning smoking, etc. into the atmosphere.
#
# 3. Ozone (O3)
# o3 gas iconOzone is composed of three oxygen atoms. It forms the protective layer which prevents entry of harmful ultraviolet radiation into the earth. The ground ozone is very harmful to human beings and the environment.
#
# 4. Nitrogen Dioxide (NO2)
# no2 gas iconNitrogen dioxide is a known highly reactive gas present in the atmosphere.
#
# 5. Sulfur Dioxide (SO2)
# so2 gas iconSulfur dioxide is a colorless gas with a burnt odor and the chemical formula SO2. The gas is acidic & corrosive in nature and can react in the atmosphere with other compounds to form sulfuric acid and other oxides of sulfur.
#
# 6. Ammonia (NH3)
# nh3 ammonia iconAmmonia is a colorless, reactive, and soluble alkaline gas with a strong pungent odor and is only used by the Indian government as a parameter of AQI.
#
# 7. Lead (Pb)
# lead iconLead is a blue-white lustrous metal belonging to the heavy metal group. It is corrosive and resistant in nature but gets easily tarnished when exposed to air.

# %%
df[~(df.AQI.isna())]
# Out:
#                 City        Date   PM2.5   PM10     NO    NO2    NOx    NH3  \
# 28         Ahmedabad  2015-01-29   83.13    NaN   6.93  28.71  33.72    NaN
# 29         Ahmedabad  2015-01-30   79.84    NaN  13.85  28.68  41.08    NaN
# 30         Ahmedabad  2015-01-31   94.52    NaN  24.39  32.66  52.61    NaN
# 31         Ahmedabad  2015-02-01  135.99    NaN  43.48  42.08  84.57    NaN
# 32         Ahmedabad  2015-02-02  178.33    NaN  54.56  35.31  72.80    NaN
# ...              ...         ...     ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27   15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28   24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29   22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30   16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01   15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
data=df.copy(deep=True)

# %%
data.sort_values(by='Date',inplace=True)

# %%
data.reset_index()
#df.drop(columns=['index'],axis=1,inplace=True)
# Out:
#        level_0  index                City        Date   PM2.5    PM10     NO  \
# 0            0      0           Ahmedabad  2015-01-01     NaN     NaN   0.92
# 1            1   7834             Chennai  2015-01-01     NaN     NaN  16.30
# 2            2  10229               Delhi  2015-01-01  313.22  607.98  69.16
# 3            3  19846             Lucknow  2015-01-01     NaN     NaN   2.11
# 4            4  21855              Mumbai  2015-01-01     NaN     NaN    NaN
# ...        ...    ...                 ...         ...     ...     ...    ...
# 29526    29526   3072           Amaravati  2020-07-01   22.00   34.00   1.50
# 29527    29527  26956             Talcher  2020-07-01   24.85   31.06  27.73
# 29528    29528  28068  Thiruvananthapuram  2020-07-01    2.00   35.00   1.68
# 29529    29529   7833          Chandigarh  2020-07-01   32.90   72.38   0.56
# 29530    29530  29530       Visakhapatnam  2020-07-01   15.00   66.00   0.40
#
# ...

# %%
data.head()
# Out:
#    index       City        Date   PM2.5    PM10     NO    NO2     NOx    NH3  \
# 0      0  Ahmedabad  2015-01-01     NaN     NaN   0.92  18.22   17.15    NaN
# 1   7834    Chennai  2015-01-01     NaN     NaN  16.30  15.39   22.68   4.59
# 2  10229      Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59  33.85
# 3  19846    Lucknow  2015-01-01     NaN     NaN   2.11  13.46    4.57    NaN
# 4  21855     Mumbai  2015-01-01     NaN     NaN    NaN    NaN   27.38    NaN
#
#       CO     SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 0   0.92   27.64  133.36     0.00     0.02    0.00    NaN        NaN
# 1   1.17    9.20   11.35     0.17      NaN     NaN    NaN        NaN
# 2  15.20    9.25   41.68    14.36    24.86    9.84  472.0     Severe
# 3  12.15  169.57   25.92     1.35     3.93     NaN    NaN        NaN
# 4   0.00     NaN     NaN     0.00     0.00    0.00    NaN        NaN

# %%
data.drop(columns=['index'],axis=1,inplace=True)

# %%
data
# Out:
#                      City        Date   PM2.5    PM10     NO    NO2     NOx  \
# 0               Ahmedabad  2015-01-01     NaN     NaN   0.92  18.22   17.15
# 1                 Chennai  2015-01-01     NaN     NaN  16.30  15.39   22.68
# 2                   Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59
# 3                 Lucknow  2015-01-01     NaN     NaN   2.11  13.46    4.57
# 4                  Mumbai  2015-01-01     NaN     NaN    NaN    NaN   27.38
# ...                   ...         ...     ...     ...    ...    ...     ...
# 29526           Amaravati  2020-07-01   22.00   34.00   1.50   9.68    6.40
# 29527             Talcher  2020-07-01   24.85   31.06  27.73  29.36   57.09
# 29528  Thiruvananthapuram  2020-07-01    2.00   35.00   1.68   2.30    2.58
# 29529          Chandigarh  2020-07-01   32.90   72.38   0.56   9.87    5.92
# 29530       Visakhapatnam  2020-07-01   15.00   66.00   0.40  26.85   14.05
#
# ...

# %%
data.groupby('City')['PM2.5'].mean()
# Out:
# City
# Ahmedabad              67.854497
# Aizawl                 17.130000
# Amaravati              37.773217
# Amritsar               55.468335
# Bengaluru              35.819828
# Bhopal                 50.059571
# Brajrajnagar           64.057610
# Chandigarh             41.130242
# Chennai                50.425613
# Coimbatore             29.151587
# Delhi                 117.196153
# Ernakulam              24.944747
# Gurugram              117.104007
# Guwahati               63.685429
# Hyderabad              47.035357
# Jaipur                 54.500708
# Jorapokhar             64.228918
# Kochi                  31.428519
# Kolkata                64.362833
# Lucknow               109.714059
# Mumbai                 35.198393
# Patna                 123.498562
# Shillong               30.823984
# Talcher                61.405425
# Thiruvananthapuram     28.036617
# Visakhapatnam          46.969610
# Name: PM2.5, dtype: float64

# %%
df_trail = df.copy(deep=True)

# %%
df_trail.sort_values(['Date'],inplace=True)

# %%
df_trail
# Out:
#                      City        Date   PM2.5    PM10     NO    NO2     NOx  \
# 0               Ahmedabad  2015-01-01     NaN     NaN   0.92  18.22   17.15
# 7834              Chennai  2015-01-01     NaN     NaN  16.30  15.39   22.68
# 10229               Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59
# 19846             Lucknow  2015-01-01     NaN     NaN   2.11  13.46    4.57
# 21855              Mumbai  2015-01-01     NaN     NaN    NaN    NaN   27.38
# ...                   ...         ...     ...     ...    ...    ...     ...
# 3072            Amaravati  2020-07-01   22.00   34.00   1.50   9.68    6.40
# 26956             Talcher  2020-07-01   24.85   31.06  27.73  29.36   57.09
# 28068  Thiruvananthapuram  2020-07-01    2.00   35.00   1.68   2.30    2.58
# 7833           Chandigarh  2020-07-01   32.90   72.38   0.56   9.87    5.92
# 29530       Visakhapatnam  2020-07-01   15.00   66.00   0.40  26.85   14.05
#
# ...

# %%
df_trail.groupby('City')['PM10'].mean()
# Out:
# City
# Ahmedabad             114.584029
# Aizawl                 23.352857
# Amaravati              76.362020
# Amritsar              115.202599
# Bengaluru              83.243287
# Bhopal                119.324321
# Brajrajnagar          124.217373
# Chandigarh             85.656546
# Chennai                62.834404
# Coimbatore             37.982137
# Delhi                 232.809229
# Ernakulam              48.335633
# Gurugram              191.504432
# Guwahati              116.604900
# Hyderabad              91.931532
# Jaipur                123.483509
# Jorapokhar            149.657942
# Kochi                  67.335432
# Kolkata               115.629499
# Lucknow                      NaN
# Mumbai                 96.745059
# Patna                 126.747958
# Shillong               42.199170
# Talcher               165.772708
# Thiruvananthapuram     52.863659
# Visakhapatnam         105.951354
# Name: PM10, dtype: float64

# %%
def fun(df_trail):
    if (df_trail.AQI_Bucket == 'Good').any():
        return df_trail

# %%
fun(df_trail)
# Out:
#                      City        Date   PM2.5    PM10     NO    NO2     NOx  \
# 0               Ahmedabad  2015-01-01     NaN     NaN   0.92  18.22   17.15
# 7834              Chennai  2015-01-01     NaN     NaN  16.30  15.39   22.68
# 10229               Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59
# 19846             Lucknow  2015-01-01     NaN     NaN   2.11  13.46    4.57
# 21855              Mumbai  2015-01-01     NaN     NaN    NaN    NaN   27.38
# ...                   ...         ...     ...     ...    ...    ...     ...
# 3072            Amaravati  2020-07-01   22.00   34.00   1.50   9.68    6.40
# 26956             Talcher  2020-07-01   24.85   31.06  27.73  29.36   57.09
# 28068  Thiruvananthapuram  2020-07-01    2.00   35.00   1.68   2.30    2.58
# 7833           Chandigarh  2020-07-01   32.90   72.38   0.56   9.87    5.92
# 29530       Visakhapatnam  2020-07-01   15.00   66.00   0.40  26.85   14.05
#
# ...

# %%
df_trail['Particulate_Matter']=df_trail['PM2.5']+df_trail['PM10']

# %%
df_trail
# Out:
#                      City        Date   PM2.5    PM10     NO    NO2     NOx  \
# 0               Ahmedabad  2015-01-01     NaN     NaN   0.92  18.22   17.15
# 7834              Chennai  2015-01-01     NaN     NaN  16.30  15.39   22.68
# 10229               Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59
# 19846             Lucknow  2015-01-01     NaN     NaN   2.11  13.46    4.57
# 21855              Mumbai  2015-01-01     NaN     NaN    NaN    NaN   27.38
# ...                   ...         ...     ...     ...    ...    ...     ...
# 3072            Amaravati  2020-07-01   22.00   34.00   1.50   9.68    6.40
# 26956             Talcher  2020-07-01   24.85   31.06  27.73  29.36   57.09
# 28068  Thiruvananthapuram  2020-07-01    2.00   35.00   1.68   2.30    2.58
# 7833           Chandigarh  2020-07-01   32.90   72.38   0.56   9.87    5.92
# 29530       Visakhapatnam  2020-07-01   15.00   66.00   0.40  26.85   14.05
#
# ...

# %%
def gettingmissingvalue(data):
    total_missing_value = data.isna().sum()
    missing_value_percentage = df_trail.isna().sum()*100/len(data)
    dataset = pd.concat([total_missing_value,round(missing_value_percentage,2)],axis=1)
    missin_values_array = dataset.rename(columns = 
                                                    {0 : 'Missing Values', 1 : '% of Total Values'})
    return missin_values_array

# %%
gettingmissingvalue(df_trail)
# Out:
#                     Missing Values  % of Total Values
# City                             0               0.00
# Date                             0               0.00
# PM2.5                         4598              15.57
# PM10                         11140              37.72
# NO                            3582              12.13
# NO2                           3585              12.14
# NOx                           4185              14.17
# NH3                          10328              34.97
# CO                            2059               6.97
# SO2                           3854              13.05
# O3                            4022              13.62
# Benzene                       5623              19.04
# Toluene                       8041              27.23
# Xylene                       18109              61.32
# AQI                              0               0.00
# AQI_Bucket                    4681              15.85
# ...

# %%
df_trail.isna().sum()
# Out:
# City                      0
# Date                      0
# PM2.5                  4598
# PM10                  11140
# NO                     3582
# NO2                    3585
# NOx                    4185
# NH3                   10328
# CO                     2059
# SO2                    3854
# O3                     4022
# Benzene                5623
# Toluene                8041
# Xylene                18109
# AQI                       0
# AQI_Bucket             4681
# Particulate_Matter    11899
# dtype: int64

# %%
df_trail['AQI']
# Out:
# 0        166.463581
# 7834     166.463581
# 10229    472.000000
# 19846    166.463581
# 21855    166.463581
#             ...
# 3072      54.000000
# 26956    101.000000
# 28068     41.000000
# 7833      66.000000
# 29530     50.000000
# Name: AQI, Length: 29531, dtype: float64
