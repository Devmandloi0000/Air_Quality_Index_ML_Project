# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("E:\\For_Job\\Internship_Ineuron\\Air_Quality_Index\\Code\\notebook\\data\\city_day.csv")

# %%
data.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
data.shape
# Out:
# (29531, 16)

# %%
data.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
from pymongo import MongoClient

# %%
url = f"mongodb+srv://devmandloi37:devmandloi@cluster0.rkgp8jf.mongodb.net/?retryWrites=true&w=majority"

# %%
client=MongoClient(url)

# %%
DB= client['Air_Quality_Index']
col=DB['Air_Quality_Index_Dataset']

# %%
data.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
my_list_data=data.to_dict(orient='records')

# %%
my_list_data
# Out:
# [{'City': 'Ahmedabad',
#   'Date': '2015-01-01',
#   'PM2.5': nan,
#   'PM10': nan,
#   'NO': 0.92,
#   'NO2': 18.22,
#   'NOx': 17.15,
#   'NH3': nan,
#   'CO': 0.92,
#   'SO2': 27.64,
#   'O3': 133.36,
#   'Benzene': 0.0,
#   'Toluene': 0.02,
#   'Xylene': 0.0,
#   'AQI': nan,
#   'AQI_Bucket': nan},
#  {'City': 'Ahmedabad',
#   'Date': '2015-01-02',
#   'PM2.5': nan,
#   'PM10': nan,
#   'NO': 0.97,
#   'NO2': 15.69,
#   'NOx': 16.46,
#   'NH3': nan,
#   'CO': 0.97,
#   'SO2': 24.55,
#   'O3': 34.06,
#   'Benzene': 3.68,
#   'Toluene': 5.5,
#   'Xylene': 3.77,
#   'AQI': nan,
#   'AQI_Bucket': nan},
#  {'City': 'Ahmedabad',
#   'Date': '2015-01-03',
#   'PM2.5': nan,
#   'PM10': nan,
#   'NO': 17.4,
#   'NO2': 19.3,
#   'NOx': 29.7,
#   'NH3': nan,
#   'CO': 17.4,
#   'SO2': 29.07,
#   'O3': 30.7,
#   'Benzene': 6.8,
#   'Toluene': 16.4,
#   'Xylene': 2.25,
#   'AQI': nan,
#   'AQI_Bucket': nan},
#  {'City': 'Ahmedabad',
#   'Date': '2015-01-04',
#   'PM2.5': nan,
# ...

# %%
#col.insert_many(my_list_data)

# %%
query={}
a= col.find(query)
df = pd.DataFrame(list(a))

# %%
df.drop('_id',inplace=True,axis=1)

# %%
df.shape
# Out:
# (29531, 16)

# %% [markdown]
# 1. Particulate Matter (PM10 & PM2.5)
# pm2.5 iconA mixture of particles with liquid droplets in the air forms particulate matter. PM 10 are particles that have a size of less than or equal to 10 microns whereas PM2.5 are ultra-fine particles having a size of less than or equal to 2.5 microns.
#
# 2. Carbon Monoxide
# co gas iconSources:
# It is a colorless gas, released from automobile emissions, fires, industrial processes, gas stoves, kitchen chimneys, generators, wood-burning smoking, etc. into the atmosphere.
#
# 3. Ozone (O3)
# o3 gas iconOzone is composed of three oxygen atoms. It forms the protective layer which prevents entry of harmful ultraviolet radiation into the earth. The ground ozone is very harmful to human beings and the environment.
#
# 4. Nitrogen Dioxide (NO2)
# no2 gas iconNitrogen dioxide is a known highly reactive gas present in the atmosphere.
#
# 5. Sulfur Dioxide (SO2)
# so2 gas iconSulfur dioxide is a colorless gas with a burnt odor and the chemical formula SO2. The gas is acidic & corrosive in nature and can react in the atmosphere with other compounds to form sulfuric acid and other oxides of sulfur.
#
# 6. Ammonia (NH3)
# nh3 ammonia iconAmmonia is a colorless, reactive, and soluble alkaline gas with a strong pungent odor and is only used by the Indian government as a parameter of AQI.
#
# 7. Lead (Pb)
# lead iconLead is a blue-white lustrous metal belonging to the heavy metal group. It is corrosive and resistant in nature but gets easily tarnished when exposed to air.

# %%
df[~(df.AQI.isna())]
# Out:
#                 City        Date   PM2.5   PM10     NO    NO2    NOx   NH3  \
# 4          Ahmedabad  2015-05-03  106.15    NaN  13.12  23.02  35.05   NaN
# 5          Ahmedabad  2015-05-27   45.49    NaN   4.26  13.73  17.10   NaN
# 6          Ahmedabad  2015-06-03  103.78    NaN   6.36  13.90  19.86   NaN
# 7          Ahmedabad  2015-06-04   25.14    NaN   6.01  18.73  24.74   NaN
# 8          Ahmedabad  2015-06-11   36.98    NaN   8.21  11.52  19.74   NaN
# ...              ...         ...     ...    ...    ...    ...    ...   ...
# 29526  Visakhapatnam  2020-03-30   21.62  65.48   6.23  24.02  17.83  5.40
# 29527  Visakhapatnam  2020-04-05   22.30  52.05  13.75  31.35  28.06  7.60
# 29528  Visakhapatnam  2020-05-18   11.18  36.23   1.47  18.69  10.97  6.78
# 29529  Visakhapatnam  2020-06-01   15.68  81.88   1.91  20.61  12.15  8.25
# 29530  Visakhapatnam  2020-06-13   22.75  86.77   3.85  38.23  22.60  9.24
#
# ...

# %%
data=df.copy(deep=True)

# %%
data.sort_values(by='Date',inplace=True)

# %%
data.groupby('City')['PM2.5'].mean()
# Out:
# City
# Ahmedabad              67.854497
# Aizawl                 17.130000
# Amaravati              37.773217
# Amritsar               55.468335
# Bengaluru              35.819828
# Bhopal                 50.059571
# Brajrajnagar           64.057610
# Chandigarh             41.130242
# Chennai                50.425613
# Coimbatore             29.151587
# Delhi                 117.196153
# Ernakulam              24.944747
# Gurugram              117.104007
# Guwahati               63.685429
# Hyderabad              47.035357
# Jaipur                 54.500708
# Jorapokhar             64.228918
# Kochi                  31.428519
# Kolkata                64.362833
# Lucknow               109.714059
# Mumbai                 35.198393
# Patna                 123.498562
# Shillong               30.823984
# Talcher                61.405425
# Thiruvananthapuram     28.036617
# Visakhapatnam          46.969610
# Name: PM2.5, dtype: float64

# %%
data.reset_index(inplace=True)
#df.drop(columns=['index'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    index       City        Date   PM2.5    PM10     NO    NO2     NOx    NH3  \
# 0  21228     Mumbai  2015-01-01     NaN     NaN    NaN    NaN   27.38    NaN
# 1  19753    Lucknow  2015-01-01     NaN     NaN   2.11  13.46    4.57    NaN
# 2  11855      Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59  33.85
# 3    259  Ahmedabad  2015-01-01     NaN     NaN   0.92  18.22   17.15    NaN
# 4   5670    Chennai  2015-01-01     NaN     NaN  16.30  15.39   22.68   4.59
#
#       CO     SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 0   0.00     NaN     NaN     0.00     0.00    0.00    NaN        NaN
# 1  12.15  169.57   25.92     1.35     3.93     NaN    NaN        NaN
# 2  15.20    9.25   41.68    14.36    24.86    9.84  472.0     Severe
# 3   0.92   27.64  133.36     0.00     0.02    0.00    NaN        NaN
# 4   1.17    9.20   11.35     0.17      NaN     NaN    NaN        NaN

# %%
data.drop(columns=['index'],axis=1,inplace=True)

# %%
data
# Out:
#              City        Date   PM2.5    PM10     NO    NO2     NOx    NH3  \
# 0          Mumbai  2015-01-01     NaN     NaN    NaN    NaN   27.38    NaN
# 1         Lucknow  2015-01-01     NaN     NaN   2.11  13.46    4.57    NaN
# 2           Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59  33.85
# 3       Ahmedabad  2015-01-01     NaN     NaN   0.92  18.22   17.15    NaN
# 4         Chennai  2015-01-01     NaN     NaN  16.30  15.39   22.68   4.59
# ...           ...         ...     ...     ...    ...    ...     ...    ...
# 29526    Guwahati  2020-07-01   40.00   53.00   0.55   6.59    3.59   5.02
# 29527    Amritsar  2020-07-01   57.67  100.99  32.81  15.11   30.20  17.73
# 29528      Bhopal  2020-07-01   14.00   30.00   1.10   5.12    3.62   8.05
# 29529  Coimbatore  2020-07-01     NaN     NaN    NaN  46.03   27.57    NaN
# 29530   Ernakulam  2020-07-01    5.88   13.91   2.58   2.40    1.60   1.44
#
# ...

# %%
data[data.City=='Ahmedabad'][80:100]
# Out:
#           City        Date   PM2.5  PM10     NO    NO2    NOx  NH3     CO  \
# 562  Ahmedabad  2015-03-22  108.59   NaN  25.38  39.34  63.01  NaN  25.38
# 570  Ahmedabad  2015-03-23  130.76   NaN  45.61  41.03  85.76  NaN  45.61
# 577  Ahmedabad  2015-03-24  143.55   NaN  27.30  31.15  57.16  NaN  27.30
# 582  Ahmedabad  2015-03-25  165.07   NaN  23.83  34.48  57.71  NaN  23.83
# 587  Ahmedabad  2015-03-26  166.85   NaN  17.93  43.30  60.07  NaN  17.93
# 594  Ahmedabad  2015-03-27  147.38   NaN   6.40  35.82  40.22  NaN   6.40
# 605  Ahmedabad  2015-03-28  158.25   NaN   5.86  27.89  32.65  NaN   5.86
# 611  Ahmedabad  2015-03-29  237.76   NaN   4.99  21.80  25.37  NaN   4.99
# 618  Ahmedabad  2015-03-30  133.37   NaN   3.88  17.99  21.02  NaN   3.88
# 626  Ahmedabad  2015-03-31  133.30   NaN   6.52  20.00  26.18  NaN   6.52
# 629  Ahmedabad  2015-04-01   96.04   NaN   3.80  20.07  23.46  NaN   3.80
# 639  Ahmedabad  2015-04-02   77.69   NaN   5.24  18.87  23.06  NaN   5.24
# ...

# %%
def getmissingvalues(data):
    missing_value = data.isna().sum()
    missing_value_percentages = data.isna().sum() * 100 / len(data)
    # no on value counts
    val_count = data.nunique()
    data_type = data.dtypes
    
    miss_val_array = pd.concat([missing_value,round(missing_value_percentages,2),val_count,data_type],axis=1)
    
    miss_val_array = miss_val_array.rename(columns={0:'total missing value',
                                                    1: '% of missing value',
                                                    2: 'Number of value counts',
                                                    3: "data type "})
    miss_val_array.reset_index()
    
    return miss_val_array

# %%
getmissingvalues(data)
# Out:
#             total missing value  % of missing value  Number of value counts  \
# City                          0                0.00                      26
# Date                          0                0.00                    2009
# PM2.5                      4598               15.57                   11716
# PM10                      11140               37.72                   12571
# NO                         3582               12.13                    5776
# NO2                        3585               12.14                    7404
# NOx                        4185               14.17                    8156
# NH3                       10328               34.97                    5922
# CO                         2059                6.97                    1779
# SO2                        3854               13.05                    4761
# O3                         4022               13.62                    7699
# ...

# %% [markdown]
# The formula for calculating a sub index is as follows:
#
# ![CPCB.jpg](attachment:CPCB.jpg)
#
#
# Sub Index for a pollutant = Upper limit of the previous AQI category to which the pollutant’s current reading would have fallen +[(current reading – upper limit of the previous reading category of the pollutant)* (width or interval of the AQI category for the current level of reading / width or interval of the current reading category of the pollutant)]

# %%
data.Date=pd.to_datetime(data.Date)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  datetime64[ns]
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: datetime64[ns](1), float64(13), object(2)
# memory usage: 3.6+ MB

# %%
data['Days']=data.Date.dt.dayofyear

# %%
data['Month']=data.Date.dt.month

# %%
data
# Out:
#              City       Date   PM2.5    PM10     NO    NO2     NOx    NH3  \
# 0          Mumbai 2015-01-01     NaN     NaN    NaN    NaN   27.38    NaN
# 1         Lucknow 2015-01-01     NaN     NaN   2.11  13.46    4.57    NaN
# 2           Delhi 2015-01-01  313.22  607.98  69.16  36.39  110.59  33.85
# 3       Ahmedabad 2015-01-01     NaN     NaN   0.92  18.22   17.15    NaN
# 4         Chennai 2015-01-01     NaN     NaN  16.30  15.39   22.68   4.59
# ...           ...        ...     ...     ...    ...    ...     ...    ...
# 29526    Guwahati 2020-07-01   40.00   53.00   0.55   6.59    3.59   5.02
# 29527    Amritsar 2020-07-01   57.67  100.99  32.81  15.11   30.20  17.73
# 29528      Bhopal 2020-07-01   14.00   30.00   1.10   5.12    3.62   8.05
# 29529  Coimbatore 2020-07-01     NaN     NaN    NaN  46.03   27.57    NaN
# 29530   Ernakulam 2020-07-01    5.88   13.91   2.58   2.40    1.60   1.44
#
#           CO     SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket  \
# ...

# %%
Ahemdabadcity=data[(data.City=='Ahmedabad')& (data.Days.isin(range(1,31))) & (data.Month == 1)]

# %%
Ahemdabadcity
# Out:
#             City       Date  PM2.5    PM10      NO    NO2    NOx  NH3      CO  \
# 3      Ahmedabad 2015-01-01    NaN     NaN    0.92  18.22  17.15  NaN    0.92
# 6      Ahmedabad 2015-01-02    NaN     NaN    0.97  15.69  16.46  NaN    0.97
# 15     Ahmedabad 2015-01-03    NaN     NaN   17.40  19.30  29.70  NaN   17.40
# 18     Ahmedabad 2015-01-04    NaN     NaN    1.70  18.48  17.97  NaN    1.70
# 28     Ahmedabad 2015-01-05    NaN     NaN   22.10  21.42  37.76  NaN   22.10
# ...          ...        ...    ...     ...     ...    ...    ...  ...     ...
# 25468  Ahmedabad 2020-01-26  62.03  191.09  118.00  12.48  74.50  NaN  118.00
# 25509  Ahmedabad 2020-01-27  33.93   85.43    9.53  30.39  21.94  NaN    9.53
# 25520  Ahmedabad 2020-01-28  18.03   66.54   11.31  18.02  17.23  NaN   11.31
# 25547  Ahmedabad 2020-01-29  28.77   73.99   20.76  21.98  25.69  NaN   20.76
# 25580  Ahmedabad 2020-01-30  41.74   92.88   36.07  26.88  38.15  NaN   36.07
#
# ...

# %%
getmissingvalues(Ahemdabadcity)
# Out:
#             total missing value  % of missing value  Number of value counts  \
# City                          0                0.00                       1
# Date                          0                0.00                     180
# PM2.5                        87               48.33                      92
# PM10                        150               83.33                      30
# NO                           61               33.89                     118
# NO2                          60               33.33                     119
# NOx                          60               33.33                     120
# NH3                         180              100.00                       0
# CO                           61               33.89                     118
# SO2                          60               33.33                     120
# O3                           61               33.89                     106
# ...

# %% [markdown]
# #### Difference
#
#
# diffrence between the mean from original data and city data
# so here we are first make assumption on any city than we make change in final data

# %%
Ahemdabadcity['PM2.5'].mean()
# Out:
# 77.29182795698925

# %%
data['PM2.5'].mean()
# Out:
# 67.45057794890306

# %%
def Fillingvalue(data):
    data['PM2.5']=data['PM2.5'].fillna(data['PM2.5'].mean())
    data['PM10']=data['PM10'].fillna(data['PM10'].mean())
    data['NO']=data['NO'].fillna(data['NO'].mean())
    data['NO2']=data['NO2'].fillna(data['NO2'].mean())
    data['NOx']=data['NOx'].fillna(data['NOx'].mean())
    data['NH3']=data['NH3'].fillna(0)
    data['CO']=data['CO'].fillna(data['CO'].mean())
    data['SO2']=data['SO2'].fillna(data['SO2'].mean())
    data['O3']=data['O3'].fillna(data['O3'].mean())
    data['Benzene']=data['Benzene'].fillna(data['Benzene'].mean())
    data['Toluene']=data['Toluene'].fillna(data['Toluene'].mean())
    data['Xylene']=data['Xylene'].fillna(data['Xylene'].mean())

# %%
Fillingvalue(Ahemdabadcity)

# %%
Ahemdabadcity
# Out:
#             City       Date      PM2.5        PM10      NO    NO2    NOx  NH3  \
# 3      Ahmedabad 2015-01-01  77.291828  113.691667    0.92  18.22  17.15  0.0
# 6      Ahmedabad 2015-01-02  77.291828  113.691667    0.97  15.69  16.46  0.0
# 15     Ahmedabad 2015-01-03  77.291828  113.691667   17.40  19.30  29.70  0.0
# 18     Ahmedabad 2015-01-04  77.291828  113.691667    1.70  18.48  17.97  0.0
# 28     Ahmedabad 2015-01-05  77.291828  113.691667   22.10  21.42  37.76  0.0
# ...          ...        ...        ...         ...     ...    ...    ...  ...
# 25468  Ahmedabad 2020-01-26  62.030000  191.090000  118.00  12.48  74.50  0.0
# 25509  Ahmedabad 2020-01-27  33.930000   85.430000    9.53  30.39  21.94  0.0
# 25520  Ahmedabad 2020-01-28  18.030000   66.540000   11.31  18.02  17.23  0.0
# 25547  Ahmedabad 2020-01-29  28.770000   73.990000   20.76  21.98  25.69  0.0
# 25580  Ahmedabad 2020-01-30  41.740000   92.880000   36.07  26.88  38.15  0.0
#
# ...

# %%
Ahemdabadcity['NH3'].unique()
# Out:
# array([0.])

# %% [markdown]
# Indian AQI	    (Indian Range for SO2 (ug/m3))	    (US AQI)	    US-EPA Range for SO2 (ppb) (1 hour)
#
#
#     0-50	        0-40	                            0-50	    0-35
#
#
#     51-100	        41-80	                            51-100	    36-75
#
#
#     101-200	        81-380	                            101-150	    76-
#
#
#     201-300	        381-800	                            151-200	    186-304
#
#
#     301-400	        801-1600	                        201-300	    305-604 (24 hours)
#
#
#     401-500	        1600+	                            301-500	    605-1004 (24 hours)

# %% [markdown]
# Sub Index for a pollutant = Upper limit of the previous AQI category to which the pollutant’s current reading would have fallen +[(current reading – upper limit of the previous reading category of the pollutant)* (width or interval of the AQI category for the current level of reading / width or interval of the current reading category of the pollutant)]

# %%
class sub_indexes:
    def __init__(self) -> None:
        pass
    
    def get_pm25_subindex(x):
        if x <= 30:
            return x * 50/30
        elif x > 30 and x <= 60:
            return 50 + (x - 30) * 50/30
        elif x > 60 and x <= 90:
            return 100 + (x- 60) * 100/30
        elif x > 90 and x <= 120:
            return 200 + (x - 90) * 100/30
        elif x > 120 and x <= 250:
            return 300 + (x - 120) * 100/130
        elif x > 250:
            return 400 + (x - 250) * 100/130
        else:
            return 0 
        
    
    def get_pm10_subindex(x):
        if x <= 50:
            return x
        elif x > 50 and x <= 100:
            return x
        elif x > 100 and x <= 250:
            return 100 + (x- 100) * 100/150
        elif x > 250 and x <= 350:
            return 200 + (x - 250)
        elif x > 350 and x <= 430:
            return 300 + (x - 350) * 100/80
        elif x > 430:
            return 400 + (x - 430) * 100/80
        else:
            return 0 
        
    def get_SO2_subindex(x):
        if x <= 40:
            return x * 50 / 40
        elif x <= 80:
            return 50 + (x - 40) * 50 / 40
        elif x <= 380:
            return 100 + (x - 80) * 100 / 300
        elif x <= 800:
            return 200 + (x - 380) * 100 / 420
        elif x <= 1600:
            return 300 + (x - 800) * 100 / 800
        elif x > 1600:
            return 400 + (x - 1600) * 100 / 800
        else:
            return 0
        
    def get_NO2_subindex(x):
        if x <= 40:
            return x * 50/40
        elif x <= 80 :
            return 50 + (x - 40) * 50 / 40
        elif x <= 180 :
            return 100 + (x - 80) * 100/100
        elif x <= 280 :
            return 200 + (x - 180) * 100/100
        elif x <= 400 :
            return 300 + (x - 280) * 100/120
        elif x > 400:
            return 400 + (x - 400) * 100/200
        else:
            return 0
        
    def get_NOx_subindex(x):
        if x <= 40:
            return x * 50 / 40
        elif x <= 80:
            return 50 + (x - 40) * 50 / 40
        elif x <= 180:
            return 100 + (x - 80) * 100 / 100
        elif x <= 280:
            return 200 + (x - 180) * 100 / 100
        elif x <= 400:
            return 300 + (x - 280) * 100 / 120
        elif x > 400:
            return 400 + (x - 400) * 100 / 120
        else:
            return 0
        
    
    def get_NH3_subindex(x):
        if x <= 200:
            return x * 50 / 200
        elif x <= 400:
            return 50 + (x - 200) * 50 / 200
        elif x <= 800:
            return 100 + (x - 400) * 100 / 400
        elif x <= 1200:
            return 200 + (x - 800) * 100 / 400
        elif x <= 1800:
            return 300 + (x - 1200) * 100 / 600
        elif x > 1800:
            return 400 + (x - 1800) * 100 / 600
        else:
            return 0
        
    def get_CO_subindex(x):
        if x <= 1:
            return x * 50 / 1
        elif x <= 2:
            return 50 + (x - 1) * 50 / 1
        elif x <= 10:
            return 100 + (x - 2) * 100 / 8
        elif x <= 17:
            return 200 + (x - 10) * 100 / 7
        elif x <= 34:
            return 300 + (x - 17) * 100 / 17
        elif x > 34:
            return 400 + (x - 34) * 100 / 17
        else:
            return 0
        
    
        
    def get_O3_subindex(x):
        if x <= 50:
            return x * 50 / 50
        elif x <= 100:
            return 50 + (x - 50) * 50 / 50
        elif x <= 168:
            return 100 + (x - 100) * 100 / 68
        elif x <= 208:
            return 200 + (x - 168) * 100 / 40
        elif x <= 748:
            return 300 + (x - 208) * 100 / 539
        elif x > 748:
            return 400 + (x - 400) * 100 / 539
        else:
            return 0

# %%
subindex_data = {
    'PM25_subindex':'PM2.5',
    'PM10_subindex':'PM10',
    'NO2_subindex' :'NO2',
    'NOx_subindex' :'NOx',
    'NH3_subindex' :'NH3',
    'CO_subindex'  :'CO',
    'SO2_subindex' :'SO2',
    'O3_subindex'  :'O3'
}


Ahemdabadcity_subindex = {}
class Final_Sub_Indexes:
    def __init__(self,SID,data) -> None:
        for i,j in SID.items():
            if j == 'PM2.5':
                Ahemdabadcity_subindex[i] = data[j].apply(lambda x : sub_indexes.get_pm25_subindex(x))
            
            if j == 'PM10':
                Ahemdabadcity_subindex[i] = data[j].apply(lambda x : sub_indexes.get_pm10_subindex(x))
                
            if j == 'NO2':
                Ahemdabadcity_subindex[i] = data[j].apply(lambda x : sub_indexes.get_NO2_subindex(x))
                
            if j == "NOx":
                Ahemdabadcity_subindex[i] = data[j].apply(lambda x : sub_indexes.get_NOx_subindex(x))
                
            if j == "NH3":
                Ahemdabadcity_subindex[i] = data[j].apply(lambda x : sub_indexes.get_NH3_subindex(x))
                
            if j == "CO":
                Ahemdabadcity_subindex[i] = data[j].apply(lambda x : sub_indexes.get_CO_subindex(x))
                
            if j == "SO2":
                Ahemdabadcity_subindex[i] = data[j].apply(lambda x : sub_indexes.get_SO2_subindex(x))
                
            if j == "O3":
                Ahemdabadcity_subindex[i] = data[j].apply(lambda x : sub_indexes.get_O3_subindex(x))
        
    def __str__(self) -> str:
        city_data = pd.DataFrame(Ahemdabadcity_subindex)
        return city_data              
   
    
f = Final_Sub_Indexes(subindex_data,Ahemdabadcity)

# %%
final_ahemdabad=pd.DataFrame(Ahemdabadcity_subindex)

# %%
final_ahemdabad
# Out:
#        PM25_subindex  PM10_subindex  NO2_subindex  NOx_subindex  NH3_subindex  \
# 3         157.639427     109.127778       22.7750       21.4375           0.0
# 6         157.639427     109.127778       19.6125       20.5750           0.0
# 15        157.639427     109.127778       24.1250       37.1250           0.0
# 18        157.639427     109.127778       23.1000       22.4625           0.0
# 28        157.639427     109.127778       26.7750       47.2000           0.0
# ...              ...            ...           ...           ...           ...
# 25468     106.766667     160.726667       15.6000       93.1250           0.0
# 25509      56.550000      85.430000       37.9875       27.4250           0.0
# 25520      30.050000      66.540000       22.5250       21.5375           0.0
# 25547      47.950000      73.990000       27.4750       32.1125           0.0
# 25580      69.566667      92.880000       33.6000       47.6875           0.0
#
# ...

# %%
final_ahemdabad.shape
# Out:
# (180, 8)

# %%
final_ahemdabad['cal_AQI']=round(final_ahemdabad[['PM25_subindex','PM10_subindex','NO2_subindex','NOx_subindex','NH3_subindex','CO_subindex','SO2_subindex','O3_subindex']].max(axis=1))

# %%
def get_categories_AQI(x):
    if x <= 50:
        return "Good"
    elif x <= 100:
        return "Satisfactory"
    elif x <= 200:
        return "Moderate"
    elif x <= 300:
        return "Poor"
    elif x <= 400:
        return "Very Poor"
    elif x > 400:
        return "Severe"
    else:
        return np.NaN
    


final_ahemdabad['AQI_bucket'] = final_ahemdabad['cal_AQI'].apply(lambda x : get_categories_AQI(x))

# %%
final_ahemdabad
# Out:
#        PM25_subindex  PM10_subindex  NO2_subindex  NOx_subindex  NH3_subindex  \
# 3         157.639427     109.127778       22.7750       21.4375           0.0
# 6         157.639427     109.127778       19.6125       20.5750           0.0
# 15        157.639427     109.127778       24.1250       37.1250           0.0
# 18        157.639427     109.127778       23.1000       22.4625           0.0
# 28        157.639427     109.127778       26.7750       47.2000           0.0
# ...              ...            ...           ...           ...           ...
# 25468     106.766667     160.726667       15.6000       93.1250           0.0
# 25509      56.550000      85.430000       37.9875       27.4250           0.0
# 25520      30.050000      66.540000       22.5250       21.5375           0.0
# 25547      47.950000      73.990000       27.4750       32.1125           0.0
# 25580      69.566667      92.880000       33.6000       47.6875           0.0
#
# ...

# %%
getmissingvalues(final_ahemdabad)
# Out:
#                total missing value  % of missing value  \
# PM25_subindex                    0                 0.0
# PM10_subindex                    0                 0.0
# NO2_subindex                     0                 0.0
# NOx_subindex                     0                 0.0
# NH3_subindex                     0                 0.0
# CO_subindex                      0                 0.0
# SO2_subindex                     0                 0.0
# O3_subindex                      0                 0.0
# cal_AQI                          0                 0.0
# AQI_bucket                       0                 0.0
#
#                Number of value counts data type
# PM25_subindex                      93    float64
# PM10_subindex                      31    float64
# NO2_subindex                      120    float64
# NOx_subindex                      121    float64
# NH3_subindex                        1    float64
# CO_subindex                       119    float64
# ...

# %%
Ahemdabadcity
# Out:
#             City       Date      PM2.5        PM10      NO    NO2    NOx  NH3  \
# 3      Ahmedabad 2015-01-01  77.291828  113.691667    0.92  18.22  17.15  0.0
# 6      Ahmedabad 2015-01-02  77.291828  113.691667    0.97  15.69  16.46  0.0
# 15     Ahmedabad 2015-01-03  77.291828  113.691667   17.40  19.30  29.70  0.0
# 18     Ahmedabad 2015-01-04  77.291828  113.691667    1.70  18.48  17.97  0.0
# 28     Ahmedabad 2015-01-05  77.291828  113.691667   22.10  21.42  37.76  0.0
# ...          ...        ...        ...         ...     ...    ...    ...  ...
# 25468  Ahmedabad 2020-01-26  62.030000  191.090000  118.00  12.48  74.50  0.0
# 25509  Ahmedabad 2020-01-27  33.930000   85.430000    9.53  30.39  21.94  0.0
# 25520  Ahmedabad 2020-01-28  18.030000   66.540000   11.31  18.02  17.23  0.0
# 25547  Ahmedabad 2020-01-29  28.770000   73.990000   20.76  21.98  25.69  0.0
# 25580  Ahmedabad 2020-01-30  41.740000   92.880000   36.07  26.88  38.15  0.0
#
# ...

# %%
Cityahemdabad=Ahemdabadcity.join(final_ahemdabad)

# %%
Cityahemdabad.head()
# Out:
#          City       Date      PM2.5        PM10     NO    NO2    NOx  NH3  \
# 3   Ahmedabad 2015-01-01  77.291828  113.691667   0.92  18.22  17.15  0.0
# 6   Ahmedabad 2015-01-02  77.291828  113.691667   0.97  15.69  16.46  0.0
# 15  Ahmedabad 2015-01-03  77.291828  113.691667  17.40  19.30  29.70  0.0
# 18  Ahmedabad 2015-01-04  77.291828  113.691667   1.70  18.48  17.97  0.0
# 28  Ahmedabad 2015-01-05  77.291828  113.691667  22.10  21.42  37.76  0.0
#
#        CO    SO2  ...  PM25_subindex  PM10_subindex  NO2_subindex  \
# 3    0.92  27.64  ...     157.639427     109.127778       22.7750
# 6    0.97  24.55  ...     157.639427     109.127778       19.6125
# 15  17.40  29.07  ...     157.639427     109.127778       24.1250
# 18   1.70  18.59  ...     157.639427     109.127778       23.1000
# 28  22.10  39.33  ...     157.639427     109.127778       26.7750
#
#     NOx_subindex  NH3_subindex CO_subindex  SO2_subindex  O3_subindex  \
# ...

# %%
import os
os.getcwd()
Cityahemdabad.to_csv(f'{os.getcwd()}\\Ahemdabadcity.csv')

# %% [markdown]
# ## FINAL DATA

# %% [markdown]
# Now for whole data
#
# first we classify our data based on city and month
#
# in india weather are changed in every month or in every city so on top of month in every city we are filling mean values
#
#
#
#
# # Link :-
#
# How AQI is influenced by Climatic Conditions.
# Climate change influences air as ambient  air pollutants  are very sensitive to meteorological conditions.
#
# Air quality is strongly dependent on weather and is therefore sensitive to climate change.
# Recent studies have provided estimates of this climate effect through correlations of air quality with meteorological variables.
#
# How is air pollution affected by weather depends-- some types of pollution are worse in the summer heat, while others are worse in cold winter weather.
# The same atmospheric conditions that create weather-- air pressure, temperature, and humidity-- also affect air quality.
#
# Because of climate warming, the Earth experiences more extreme weather, such as heat waves and drought, which can negatively Impact air quality.

# %%
data.head()
# Out:
#         City       Date   PM2.5    PM10     NO    NO2     NOx    NH3     CO  \
# 0     Mumbai 2015-01-01     NaN     NaN    NaN    NaN   27.38    NaN   0.00
# 1    Lucknow 2015-01-01     NaN     NaN   2.11  13.46    4.57    NaN  12.15
# 2      Delhi 2015-01-01  313.22  607.98  69.16  36.39  110.59  33.85  15.20
# 3  Ahmedabad 2015-01-01     NaN     NaN   0.92  18.22   17.15    NaN   0.92
# 4    Chennai 2015-01-01     NaN     NaN  16.30  15.39   22.68   4.59   1.17
#
#       SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket  Days  Month
# 0     NaN     NaN     0.00     0.00    0.00    NaN        NaN     1      1
# 1  169.57   25.92     1.35     3.93     NaN    NaN        NaN     1      1
# 2    9.25   41.68    14.36    24.86    9.84  472.0     Severe     1      1
# 3   27.64  133.36     0.00     0.02    0.00    NaN        NaN     1      1
# 4    9.20   11.35     0.17      NaN     NaN    NaN        NaN     1      1

# %%
copy_data = data.copy(deep=True)

# %%
"""
class DataHandling:
    
    def __init__(self) -> None:
        pass
        
    def Fillingvalue(self,data):
        data['PM2.5']=data['PM2.5'].fillna(data['PM2.5'].mean())
        data['PM10']=data['PM10'].fillna(data['PM10'].mean())
        data['NO']=data['NO'].fillna(data['NO'].mean())
        data['NO2']=data['NO2'].fillna(data['NO2'].mean())
        data['NOx']=data['NOx'].fillna(data['NOx'].mean())
        data['NH3']=data['NH3'].fillna(0)
        data['CO']=data['CO'].fillna(data['CO'].mean())
        data['SO2']=data['SO2'].fillna(data['SO2'].mean())
        data['O3']=data['O3'].fillna(data['O3'].mean())
        data['Benzene']=data['Benzene'].fillna(data['Benzene'].mean())
        data['Toluene']=data['Toluene'].fillna(data['Toluene'].mean())
        data['Xylene']=data['Xylene'].fillna(data['Xylene'].mean())
        
        return data
        
    def CityBased(self,data) -> list:
        try:
            city_list_data=sorted(data.City.value_counts().index.tolist())
            result_data = pd.DataFrame(columns=data.columns) 
            
            for city in city_list_data:           
                for month in range(1,13):
                    data=data[(data['City'] == city) & (data['Month'] == month)].copy()
                    data = self.Fillingvalue(data)
                    
                    return_data = pd.concat([result_data,data],ignore_index=True)
                    # Ahemdabadcity=data[(data.City=='Ahmedabad')& (data.Days.isin(range(1,31))) & (data.Month == 1)]
            return return_data
                
                
                
                
        except Exception as e:
            print(f"there may be error in the city based method {e}")  
    """
# Out:
# '\nclass DataHandling:\n    \n    def __init__(self) -> None:\n        pass\n        \n    def Fillingvalue(self,data):\n        data[\'PM2.5\']=data[\'PM2.5\'].fillna(data[\'PM2.5\'].mean())\n        data[\'PM10\']=data[\'PM10\'].fillna(data[\'PM10\'].mean())\n        data[\'NO\']=data[\'NO\'].fillna(data[\'NO\'].mean())\n        data[\'NO2\']=data[\'NO2\'].fillna(data[\'NO2\'].mean())\n        data[\'NOx\']=data[\'NOx\'].fillna(data[\'NOx\'].mean())\n        data[\'NH3\']=data[\'NH3\'].fillna(0)\n        data[\'CO\']=data[\'CO\'].fillna(data[\'CO\'].mean())\n        data[\'SO2\']=data[\'SO2\'].fillna(data[\'SO2\'].mean())\n        data[\'O3\']=data[\'O3\'].fillna(data[\'O3\'].mean())\n        data[\'Benzene\']=data[\'Benzene\'].fillna(data[\'Benzene\'].mean())\n        data[\'Toluene\']=data[\'Toluene\'].fillna(data[\'Toluene\'].mean())\n        data[\'Xylene\']=data[\'Xylene\'].fillna(data[\'Xylene\'].mean())\n        \n        return data\n        \n    def CityBased(self,data) -
# ...

# %%
class DataHandling:
    
    def __init__(self) -> None:
        pass
        
    def Fillingvalue(self, data):
        data['PM2.5']=data['PM2.5'].fillna(data['PM2.5'].mean())
        data['PM10']=data['PM10'].fillna(data['PM10'].mean())
        data['NO']=data['NO'].fillna(data['NO'].mean())
        data['NO2']=data['NO2'].fillna(data['NO2'].mean())
        data['NOx']=data['NOx'].fillna(data['NOx'].mean())
        data['NH3']=data['NH3'].fillna(data['NH3'].mean())
        data['CO']=data['CO'].fillna(data['CO'].mean())
        data['SO2']=data['SO2'].fillna(data['SO2'].mean())
        data['O3']=data['O3'].fillna(data['O3'].mean())
        data['Benzene']=data['Benzene'].fillna(data['Benzene'].mean())
        data['Toluene']=data['Toluene'].fillna(data['Toluene'].mean())
        data['Xylene']=data['Xylene'].fillna(data['Xylene'].mean())
        
        return data
        
    def CityBased(self, data) -> pd.DataFrame:
        try:
            city_list_data = sorted(data.City.value_counts().index.tolist())
            result_data = pd.DataFrame(columns=data.columns)  
            
            for city in city_list_data:
                for month in range(1, 13):
                    city_month_data = data[(data['City'] == city) & (data['Month'] == month)].copy()
                    
                    if not city_month_data.empty:
                        city_month_data = self.Fillingvalue(city_month_data)
                        result_data = pd.concat([result_data, city_month_data], ignore_index=True)
                    else:
                        print(f"No data for {city}, Month {month}")
                    
            return result_data
                
        except Exception as e:
            print(f"There may be an error in the CityBased method: {e}")

# %%
change = DataHandling()
new_data=change.CityBased(copy_data)
# Out:
# No data for Aizawl, Month 1
# No data for Aizawl, Month 2
# No data for Aizawl, Month 8
# No data for Aizawl, Month 9
# No data for Aizawl, Month 10
# No data for Aizawl, Month 11
# No data for Aizawl, Month 12
# No data for Bhopal, Month 8
# No data for Chandigarh, Month 8
# No data for Ernakulam, Month 8
# No data for Ernakulam, Month 9
# No data for Ernakulam, Month 10
# No data for Ernakulam, Month 11
# No data for Ernakulam, Month 12
# No data for Kochi, Month 8
# No data for Kochi, Month 9
# No data for Kochi, Month 10
# No data for Kochi, Month 11
# No data for Kochi, Month 12

# %%
new_data
# Out:
#                 City       Date      PM2.5        PM10     NO    NO2    NOx  \
# 0          Ahmedabad 2015-01-01  77.719897  113.567419   0.92  18.22  17.15
# 1          Ahmedabad 2015-01-02  77.719897  113.567419   0.97  15.69  16.46
# 2          Ahmedabad 2015-01-03  77.719897  113.567419  17.40  19.30  29.70
# 3          Ahmedabad 2015-01-04  77.719897  113.567419   1.70  18.48  17.97
# 4          Ahmedabad 2015-01-05  77.719897  113.567419  22.10  21.42  37.76
# ...              ...        ...        ...         ...    ...    ...    ...
# 29526  Visakhapatnam 2019-12-27  51.790000  119.434286  34.78  48.39  54.01
# 29527  Visakhapatnam 2019-12-28  74.530000  119.434286   4.21  33.50  21.25
# 29528  Visakhapatnam 2019-12-29  41.000000  119.434286   2.37  20.94  13.07
# 29529  Visakhapatnam 2019-12-30  44.790000  119.434286   3.22  35.67  21.58
# 29530  Visakhapatnam 2019-12-31  52.330000   99.330000   3.51  33.70  20.78
#
# ...

# %%
new_data[(new_data['City']=='Patna')&(new_data['Month']==9)]['PM10']
# Out:
# 25112   NaN
# 25113   NaN
# 25114   NaN
# 25115   NaN
# 25116   NaN
#          ..
# 25257   NaN
# 25258   NaN
# 25259   NaN
# 25260   NaN
# 25261   NaN
# Name: PM10, Length: 150, dtype: float64

# %%
new_data[new_data['City']=='Patna'].isna().sum()
# Out:
# City            0
# Date            0
# PM2.5           0
# PM10          610
# NO              0
# NO2             0
# NOx             0
# NH3           610
# CO              0
# SO2             0
# O3              0
# Benzene         0
# Toluene         0
# Xylene          0
# AQI           399
# AQI_Bucket    399
# Days            0
# Month           0
# dtype: int64

# %%
new_data[(new_data['City']=='Patna')& (new_data['PM10'].isnull())]['Month'].value_counts()
# Out:
# Month
# 8     155
# 10    155
# 9     150
# 11    150
# Name: count, dtype: int64

# %%
data['City'].value_counts()
# Out:
# City
# Mumbai                2009
# Lucknow               2009
# Delhi                 2009
# Ahmedabad             2009
# Chennai               2009
# Bengaluru             2009
# Hyderabad             2006
# Patna                 1858
# Gurugram              1679
# Visakhapatnam         1462
# Amritsar              1221
# Jorapokhar            1169
# Jaipur                1114
# Thiruvananthapuram    1112
# Amaravati              951
# Brajrajnagar           938
# Talcher                925
# Kolkata                814
# Guwahati               502
# Coimbatore             386
# Shillong               310
# Chandigarh             304
# Bhopal                 289
# Ernakulam              162
# Kochi                  162
# Aizawl                 113
# Name: count, dtype: int64

# %%
new_data['PM2.5']=new_data['PM2.5'].fillna(new_data['PM2.5'].mean())
new_data['PM10']=new_data['PM10'].fillna(new_data['PM10'].mean())
new_data['NO']=new_data['NO'].fillna(new_data['NO'].mean())
new_data['NO2']=new_data['NO2'].fillna(new_data['NO2'].mean())
new_data['NOx']=new_data['NOx'].fillna(new_data['NOx'].mean())
new_data['NH3']=new_data['NH3'].fillna(new_data['NH3'].mean())
new_data['CO']=new_data['CO'].fillna(new_data['CO'].mean())
new_data['SO2']=new_data['SO2'].fillna(new_data['SO2'].mean())
new_data['O3']=new_data['O3'].fillna(new_data['O3'].mean())
new_data['Benzene']=new_data['Benzene'].fillna(new_data['Benzene'].mean())
new_data['Toluene']=new_data['Toluene'].fillna(new_data['Toluene'].mean())
new_data['Xylene']=new_data['Xylene'].fillna(new_data['Xylene'].mean())

# %%
getmissingvalues(new_data)
# Out:
#             total missing value  % of missing value  Number of value counts  \
# City                          0                0.00                      26
# Date                          0                0.00                    2009
# PM2.5                         0                0.00                   11889
# PM10                          0                0.00                   12746
# NO                            0                0.00                    5929
# NO2                           0                0.00                    7558
# NOx                           0                0.00                    8299
# NH3                           0                0.00                    6088
# CO                            0                0.00                    1913
# SO2                           0                0.00                    4920
# O3                            0                0.00                    7867
# ...

# %%
class sub_indexes:
    def __init__(self) -> None:
        pass
    
    def get_pm25_subindex(x):
        if x <= 30:
            return x * 50/30
        elif x > 30 and x <= 60:
            return 50 + (x - 30) * 50/30
        elif x > 60 and x <= 90:
            return 100 + (x- 60) * 100/30
        elif x > 90 and x <= 120:
            return 200 + (x - 90) * 100/30
        elif x > 120 and x <= 250:
            return 300 + (x - 120) * 100/130
        elif x > 250:
            return 400 + (x - 250) * 100/130
        else:
            return 0 
        
    
    def get_pm10_subindex(x):
        if x <= 50:
            return x
        elif x > 50 and x <= 100:
            return x
        elif x > 100 and x <= 250:
            return 100 + (x- 100) * 100/150
        elif x > 250 and x <= 350:
            return 200 + (x - 250)
        elif x > 350 and x <= 430:
            return 300 + (x - 350) * 100/80
        elif x > 430:
            return 400 + (x - 430) * 100/80
        else:
            return 0 
        
    def get_SO2_subindex(x):
        if x <= 40:
            return x * 50 / 40
        elif x <= 80:
            return 50 + (x - 40) * 50 / 40
        elif x <= 380:
            return 100 + (x - 80) * 100 / 300
        elif x <= 800:
            return 200 + (x - 380) * 100 / 420
        elif x <= 1600:
            return 300 + (x - 800) * 100 / 800
        elif x > 1600:
            return 400 + (x - 1600) * 100 / 800
        else:
            return 0
        
    def get_NO2_subindex(x):
        if x <= 40:
            return x * 50/40
        elif x <= 80 :
            return 50 + (x - 40) * 50 / 40
        elif x <= 180 :
            return 100 + (x - 80) * 100/100
        elif x <= 280 :
            return 200 + (x - 180) * 100/100
        elif x <= 400 :
            return 300 + (x - 280) * 100/120
        elif x > 400:
            return 400 + (x - 400) * 100/200
        else:
            return 0
        
    def get_NOx_subindex(x):
        if x <= 40:
            return x * 50 / 40
        elif x <= 80:
            return 50 + (x - 40) * 50 / 40
        elif x <= 180:
            return 100 + (x - 80) * 100 / 100
        elif x <= 280:
            return 200 + (x - 180) * 100 / 100
        elif x <= 400:
            return 300 + (x - 280) * 100 / 120
        elif x > 400:
            return 400 + (x - 400) * 100 / 120
        else:
            return 0
        
    
    def get_NH3_subindex(x):
        if x <= 200:
            return x * 50 / 200
        elif x <= 400:
            return 50 + (x - 200) * 50 / 200
        elif x <= 800:
            return 100 + (x - 400) * 100 / 400
        elif x <= 1200:
            return 200 + (x - 800) * 100 / 400
        elif x <= 1800:
            return 300 + (x - 1200) * 100 / 600
        elif x > 1800:
            return 400 + (x - 1800) * 100 / 600
        else:
            return 0
        
    def get_CO_subindex(x):
        if x <= 1:
            return x * 50 / 1
        elif x <= 2:
            return 50 + (x - 1) * 50 / 1
        elif x <= 10:
            return 100 + (x - 2) * 100 / 8
        elif x <= 17:
            return 200 + (x - 10) * 100 / 7
        elif x <= 34:
            return 300 + (x - 17) * 100 / 17
        elif x > 34:
            return 400 + (x - 34) * 100 / 17
        else:
            return 0
        
    
        
    def get_O3_subindex(x):
        if x <= 50:
            return x * 50 / 50
        elif x <= 100:
            return 50 + (x - 50) * 50 / 50
        elif x <= 168:
            return 100 + (x - 100) * 100 / 68
        elif x <= 208:
            return 200 + (x - 168) * 100 / 40
        elif x <= 748:
            return 300 + (x - 208) * 100 / 539
        elif x > 748:
            return 400 + (x - 400) * 100 / 539
        else:
            return 0

# %%
subindex_data = {
    'PM25_subindex':'PM2.5',
    'PM10_subindex':'PM10',
    'NO2_subindex' :'NO2',
    'NOx_subindex' :'NOx',
    'NH3_subindex' :'NH3',
    'CO_subindex'  :'CO',
    'SO2_subindex' :'SO2',
    'O3_subindex'  :'O3'
}


data_subindex = {}
class Final_Sub_Indexes:
    def __init__(self,SID,data) -> None:
        for i,j in SID.items():
            if j == 'PM2.5':
                data_subindex[i] = data[j].apply(lambda x : sub_indexes.get_pm25_subindex(x))
            
            if j == 'PM10':
                data_subindex[i] = data[j].apply(lambda x : sub_indexes.get_pm10_subindex(x))
                
            if j == 'NO2':
                data_subindex[i] = data[j].apply(lambda x : sub_indexes.get_NO2_subindex(x))
                
            if j == "NOx":
                data_subindex[i] = data[j].apply(lambda x : sub_indexes.get_NOx_subindex(x))
                
            if j == "NH3":
                data_subindex[i] = data[j].apply(lambda x : sub_indexes.get_NH3_subindex(x))
                
            if j == "CO":
                data_subindex[i] = data[j].apply(lambda x : sub_indexes.get_CO_subindex(x))
                
            if j == "SO2":
                data_subindex[i] = data[j].apply(lambda x : sub_indexes.get_SO2_subindex(x))
                
            if j == "O3":
                data_subindex[i] = data[j].apply(lambda x : sub_indexes.get_O3_subindex(x))
        
    def __str__(self) -> str:
        city_data = pd.DataFrame(data_subindex)
        return city_data              
   
    
subindex_data = Final_Sub_Indexes(subindex_data,new_data)

#subindex_data['cal_AQI']=round(subindex_data[['PM25_subindex','PM10_subindex','NO2_subindex','NOx_subindex','NH3_subindex','CO_subindex','SO2_subindex','O3_subindex']].max(axis=1))

# %%
index_data=pd.DataFrame(data_subindex)

# %%
index_data['cal_AQI']=round(index_data[['PM25_subindex','PM10_subindex','NO2_subindex','NOx_subindex','NH3_subindex','CO_subindex','SO2_subindex','O3_subindex']].max(axis=1))

# %%
index_data
# Out:
#        PM25_subindex  PM10_subindex  NO2_subindex  NOx_subindex  NH3_subindex  \
# 0         159.066323     109.044946       22.7750       21.4375      5.684868
# 1         159.066323     109.044946       19.6125       20.5750      5.684868
# 2         159.066323     109.044946       24.1250       37.1250      5.684868
# 3         159.066323     109.044946       23.1000       22.4625      5.684868
# 4         159.066323     109.044946       26.7750       47.2000      5.684868
# ...              ...            ...           ...           ...           ...
# 29526      86.316667     112.956190       60.4875       67.5125      2.390000
# 29527     148.433333     112.956190       41.8750       26.5625      2.430000
# 29528      68.333333     112.956190       26.1750       16.3375      1.695000
# 29529      74.650000     112.956190       44.5875       26.9750      2.785000
# 29530      87.216667      99.330000       42.1250       25.9750      2.922500
#
# ...

# %%
def get_categories_AQI(x):
    if x <= 50:
        return "Good"
    elif x <= 100:
        return "Satisfactory"
    elif x <= 200:
        return "Moderate"
    elif x <= 300:
        return "Poor"
    elif x <= 400:
        return "Very Poor"
    elif x > 400:
        return "Severe"
    else:
        return np.NaN
    


index_data['AQI_bucket'] = index_data['cal_AQI'].apply(lambda x : get_categories_AQI(x))

# %%
index_data
# Out:
#        PM25_subindex  PM10_subindex  NO2_subindex  NOx_subindex  NH3_subindex  \
# 0         159.066323     109.044946       22.7750       21.4375      5.684868
# 1         159.066323     109.044946       19.6125       20.5750      5.684868
# 2         159.066323     109.044946       24.1250       37.1250      5.684868
# 3         159.066323     109.044946       23.1000       22.4625      5.684868
# 4         159.066323     109.044946       26.7750       47.2000      5.684868
# ...              ...            ...           ...           ...           ...
# 29526      86.316667     112.956190       60.4875       67.5125      2.390000
# 29527     148.433333     112.956190       41.8750       26.5625      2.430000
# 29528      68.333333     112.956190       26.1750       16.3375      1.695000
# 29529      74.650000     112.956190       44.5875       26.9750      2.785000
# 29530      87.216667      99.330000       42.1250       25.9750      2.922500
#
# ...

# %%
data=new_data.join(index_data)

# %%
data.head()
# Out:
#         City       Date      PM2.5        PM10     NO    NO2    NOx  \
# 0  Ahmedabad 2015-01-01  77.719897  113.567419   0.92  18.22  17.15
# 1  Ahmedabad 2015-01-02  77.719897  113.567419   0.97  15.69  16.46
# 2  Ahmedabad 2015-01-03  77.719897  113.567419  17.40  19.30  29.70
# 3  Ahmedabad 2015-01-04  77.719897  113.567419   1.70  18.48  17.97
# 4  Ahmedabad 2015-01-05  77.719897  113.567419  22.10  21.42  37.76
#
#          NH3     CO    SO2  ...  PM25_subindex  PM10_subindex  NO2_subindex  \
# 0  22.739473   0.92  27.64  ...     159.066323     109.044946       22.7750
# 1  22.739473   0.97  24.55  ...     159.066323     109.044946       19.6125
# 2  22.739473  17.40  29.07  ...     159.066323     109.044946       24.1250
# 3  22.739473   1.70  18.59  ...     159.066323     109.044946       23.1000
# 4  22.739473  22.10  39.33  ...     159.066323     109.044946       26.7750
#
#    NOx_subindex  NH3_subindex CO_subindex SO2_subindex O3_subindex  cal_AQI  \
# ...

# %%
data.isna().sum()
# Out:
# City                0
# Date                0
# PM2.5               0
# PM10                0
# NO                  0
# NO2                 0
# NOx                 0
# NH3                 0
# CO                  0
# SO2                 0
# O3                  0
# Benzene             0
# Toluene             0
# Xylene              0
# AQI              4681
# AQI_Bucket       4681
# Days                0
# Month               0
# PM25_subindex       0
# PM10_subindex       0
# NO2_subindex        0
# NOx_subindex        0
# NH3_subindex        0
# CO_subindex         0
# SO2_subindex        0
# O3_subindex         0
# cal_AQI             0
# AQI_bucket          0
# dtype: int64

# %%
data[['AQI','cal_AQI','O3']][200:220]
# Out:
#         AQI  cal_AQI         O3
# 200   475.0    279.0  33.780000
# 201   536.0    317.0  30.570000
# 202   479.0    285.0  36.200000
# 203   592.0    289.0  37.430000
# 204   427.0    260.0  31.940000
# 205   588.0    399.0  40.980000
# 206  1141.0    564.0  33.550000
# 207   669.0    467.0  34.770000
# 208  1247.0    657.0  37.300000
# 209   411.0    296.0  38.800000
# 210   292.0    130.0  67.250000
# 211     NaN    394.0  46.128148
# 212     NaN    394.0  46.128148
# 213     NaN    394.0  46.128148
# 214     NaN    394.0  46.128148
# 215     NaN    394.0  46.128148
# 216     NaN    394.0  46.128148
# 217     NaN    394.0  46.128148
# 218     NaN    394.0  46.128148
# 219     NaN    394.0  46.128148

# %%
data
# Out:
#                 City       Date      PM2.5        PM10     NO    NO2    NOx  \
# 0          Ahmedabad 2015-01-01  77.719897  113.567419   0.92  18.22  17.15
# 1          Ahmedabad 2015-01-02  77.719897  113.567419   0.97  15.69  16.46
# 2          Ahmedabad 2015-01-03  77.719897  113.567419  17.40  19.30  29.70
# 3          Ahmedabad 2015-01-04  77.719897  113.567419   1.70  18.48  17.97
# 4          Ahmedabad 2015-01-05  77.719897  113.567419  22.10  21.42  37.76
# ...              ...        ...        ...         ...    ...    ...    ...
# 29526  Visakhapatnam 2019-12-27  51.790000  119.434286  34.78  48.39  54.01
# 29527  Visakhapatnam 2019-12-28  74.530000  119.434286   4.21  33.50  21.25
# 29528  Visakhapatnam 2019-12-29  41.000000  119.434286   2.37  20.94  13.07
# 29529  Visakhapatnam 2019-12-30  44.790000  119.434286   3.22  35.67  21.58
# 29530  Visakhapatnam 2019-12-31  52.330000   99.330000   3.51  33.70  20.78
#
# ...

# %%
sub_indexes.get_pm10_subindex(99.330000)
# Out:
# 99.33

# %%
data['cal_AQI'][500:520]-data['AQI'][500:520]
# Out:
# 500    -38.0
# 501   -276.0
# 502   -553.0
# 503   -563.0
# 504    -79.0
# 505   -123.0
# 506    -40.0
# 507   -898.0
# 508   -728.0
# 509   -469.0
# 510   -245.0
# 511   -144.0
# 512   -172.0
# 513   -135.0
# 514    -78.0
# 515    -81.0
# 516    -98.0
# 517   -128.0
# 518   -152.0
# 519    -26.0
# dtype: float64

# %%
data[data.AQI.isna()]
# Out:
#                 City       Date       PM2.5        PM10         NO        NO2  \
# 0          Ahmedabad 2015-01-01   77.719897  113.567419   0.920000  18.220000
# 1          Ahmedabad 2015-01-02   77.719897  113.567419   0.970000  15.690000
# 2          Ahmedabad 2015-01-03   77.719897  113.567419  17.400000  19.300000
# 3          Ahmedabad 2015-01-04   77.719897  113.567419   1.700000  18.480000
# 4          Ahmedabad 2015-01-05   77.719897  113.567419  22.100000  21.420000
# ...              ...        ...         ...         ...        ...        ...
# 29471  Visakhapatnam 2018-12-03   67.425574  119.434286  11.931639  40.520164
# 29472  Visakhapatnam 2018-12-04   82.230000  143.070000   3.670000  30.500000
# 29476  Visakhapatnam 2018-12-08  104.420000  166.150000   3.660000  26.010000
# 29499  Visakhapatnam 2018-12-31   67.620000  147.920000  21.630000  82.710000
# 29529  Visakhapatnam 2019-12-30   44.790000  119.434286   3.220000  35.670000
#
# ...

# %%
df_trail = df.copy(deep=True)

# %%
df_trail.sort_values(['Date'],inplace=True)

# %%
df_trail
# Out:
#                      City        Date   PM2.5    PM10     NO    NO2     NOx  \
# 0               Ahmedabad  2015-01-01     NaN     NaN   0.92  18.22   17.15
# 7834              Chennai  2015-01-01     NaN     NaN  16.30  15.39   22.68
# 10229               Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59
# 19846             Lucknow  2015-01-01     NaN     NaN   2.11  13.46    4.57
# 21855              Mumbai  2015-01-01     NaN     NaN    NaN    NaN   27.38
# ...                   ...         ...     ...     ...    ...    ...     ...
# 3072            Amaravati  2020-07-01   22.00   34.00   1.50   9.68    6.40
# 26956             Talcher  2020-07-01   24.85   31.06  27.73  29.36   57.09
# 28068  Thiruvananthapuram  2020-07-01    2.00   35.00   1.68   2.30    2.58
# 7833           Chandigarh  2020-07-01   32.90   72.38   0.56   9.87    5.92
# 29530       Visakhapatnam  2020-07-01   15.00   66.00   0.40  26.85   14.05
#
# ...

# %%
df_trail.groupby('City')['PM10'].mean()
# Out:
# City
# Ahmedabad             114.584029
# Aizawl                 23.352857
# Amaravati              76.362020
# Amritsar              115.202599
# Bengaluru              83.243287
# Bhopal                119.324321
# Brajrajnagar          124.217373
# Chandigarh             85.656546
# Chennai                62.834404
# Coimbatore             37.982137
# Delhi                 232.809229
# Ernakulam              48.335633
# Gurugram              191.504432
# Guwahati              116.604900
# Hyderabad              91.931532
# Jaipur                123.483509
# Jorapokhar            149.657942
# Kochi                  67.335432
# Kolkata               115.629499
# Lucknow                      NaN
# Mumbai                 96.745059
# Patna                 126.747958
# Shillong               42.199170
# Talcher               165.772708
# Thiruvananthapuram     52.863659
# Visakhapatnam         105.951354
# Name: PM10, dtype: float64

# %%
def fun(df_trail):
    if (df_trail.AQI_Bucket == 'Good').any():
        return df_trail

# %%
fun(df_trail)
# Out:
#                      City        Date   PM2.5    PM10     NO    NO2     NOx  \
# 0               Ahmedabad  2015-01-01     NaN     NaN   0.92  18.22   17.15
# 7834              Chennai  2015-01-01     NaN     NaN  16.30  15.39   22.68
# 10229               Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59
# 19846             Lucknow  2015-01-01     NaN     NaN   2.11  13.46    4.57
# 21855              Mumbai  2015-01-01     NaN     NaN    NaN    NaN   27.38
# ...                   ...         ...     ...     ...    ...    ...     ...
# 3072            Amaravati  2020-07-01   22.00   34.00   1.50   9.68    6.40
# 26956             Talcher  2020-07-01   24.85   31.06  27.73  29.36   57.09
# 28068  Thiruvananthapuram  2020-07-01    2.00   35.00   1.68   2.30    2.58
# 7833           Chandigarh  2020-07-01   32.90   72.38   0.56   9.87    5.92
# 29530       Visakhapatnam  2020-07-01   15.00   66.00   0.40  26.85   14.05
#
# ...

# %%
df_trail['Particulate_Matter']=df_trail['PM2.5']+df_trail['PM10']

# %%
df_trail
# Out:
#                      City        Date   PM2.5    PM10     NO    NO2     NOx  \
# 0               Ahmedabad  2015-01-01     NaN     NaN   0.92  18.22   17.15
# 7834              Chennai  2015-01-01     NaN     NaN  16.30  15.39   22.68
# 10229               Delhi  2015-01-01  313.22  607.98  69.16  36.39  110.59
# 19846             Lucknow  2015-01-01     NaN     NaN   2.11  13.46    4.57
# 21855              Mumbai  2015-01-01     NaN     NaN    NaN    NaN   27.38
# ...                   ...         ...     ...     ...    ...    ...     ...
# 3072            Amaravati  2020-07-01   22.00   34.00   1.50   9.68    6.40
# 26956             Talcher  2020-07-01   24.85   31.06  27.73  29.36   57.09
# 28068  Thiruvananthapuram  2020-07-01    2.00   35.00   1.68   2.30    2.58
# 7833           Chandigarh  2020-07-01   32.90   72.38   0.56   9.87    5.92
# 29530       Visakhapatnam  2020-07-01   15.00   66.00   0.40  26.85   14.05
#
# ...

# %%
def gettingmissingvalue(data):
    total_missing_value = data.isna().sum()
    missing_value_percentage = df_trail.isna().sum()*100/len(data)
    dataset = pd.concat([total_missing_value,round(missing_value_percentage,2)],axis=1)
    missin_values_array = dataset.rename(columns = 
                                                    {0 : 'Missing Values', 1 : '% of Total Values'})
    return missin_values_array

# %%
gettingmissingvalue(df_trail)
# Out:
#                     Missing Values  % of Total Values
# City                             0               0.00
# Date                             0               0.00
# PM2.5                         4598              15.57
# PM10                         11140              37.72
# NO                            3582              12.13
# NO2                           3585              12.14
# NOx                           4185              14.17
# NH3                          10328              34.97
# CO                            2059               6.97
# SO2                           3854              13.05
# O3                            4022              13.62
# Benzene                       5623              19.04
# Toluene                       8041              27.23
# Xylene                       18109              61.32
# AQI                              0               0.00
# AQI_Bucket                    4681              15.85
# ...

# %%
df_trail.isna().sum()
# Out:
# City                      0
# Date                      0
# PM2.5                  4598
# PM10                  11140
# NO                     3582
# NO2                    3585
# NOx                    4185
# NH3                   10328
# CO                     2059
# SO2                    3854
# O3                     4022
# Benzene                5623
# Toluene                8041
# Xylene                18109
# AQI                       0
# AQI_Bucket             4681
# Particulate_Matter    11899
# dtype: int64

# %%
df_trail['AQI']
# Out:
# 0        166.463581
# 7834     166.463581
# 10229    472.000000
# 19846    166.463581
# 21855    166.463581
#             ...
# 3072      54.000000
# 26956    101.000000
# 28068     41.000000
# 7833      66.000000
# 29530     50.000000
# Name: AQI, Length: 29531, dtype: float64
